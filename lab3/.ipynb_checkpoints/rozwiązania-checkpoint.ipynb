# %% [markdown]
# # Zadanie 1

# %%
import cv2 as cv
import numpy as np
from matplotlib import pyplot as plt

plt.rcParams["figure.figsize"] = (18, 10)

image = cv.imread("images/example.jpg")
image = cv.cvtColor(image, cv.COLOR_BGR2RGB)

kernel = [
    [-1, -1, -1],
    [-1, 8, -1],
    [-1, -1, -1],
]

kernel = np.asarray(kernel)

filtered_image = cv.filter2D(image, -1, kernel=kernel)
plt.imshow(filtered_image)

# %% [markdown]
# # Zadanie 2

# %%
import cv2 as cv
import numpy as np
from matplotlib import pyplot as plt

plt.rcParams["figure.figsize"] = (18, 10)

image = cv.imread("images/example.jpg")
image = cv.cvtColor(image, cv.COLOR_BGR2RGB)

new_image = np.array(image, dtype='float32')

new_image /= 255

matrix = [
    [0.393, 0.769, 0.189],
    [0.349, 0.689, 0.168],
    [0.272, 0.534, 0.131],
]

for i in range(len(new_image)):
    for j in range(len(new_image[i])):
        new_image[i][j][0] = np.dot(matrix[0], new_image[i][j])
        new_image[i][j][1] = np.dot(matrix[1], new_image[i][j])
        new_image[i][j][2] = np.dot(matrix[2], new_image[i][j])
        for z in range(len(new_image[i][j])):            
            if new_image[i][j][z] > 1:
                new_image[i][j][z] = 1

plt.imshow(new_image)

# %% [markdown]
# # Zadanie 3

# %%
import cv2 as cv
import numpy as np
from matplotlib import pyplot as plt

plt.rcParams["figure.figsize"] = (18, 10)
fig, ax = plt.subplots(1, 5)

image = cv.imread("images/example.jpg")
image = cv.cvtColor(image, cv.COLOR_BGR2RGB)

new_image = image.copy()
new_imageYCrCb = image.copy()

ax[0].imshow(new_image)

matrix = [
    [0.229, 0.587, 0.114],
    [0.500, -0.418, -0.082],
    [-0.168, -0.331, 0.500],
]

for i in range(len(new_image)):
    for j in range(len(new_image[i])):
        new_imageYCrCb[i][j][0] = np.dot(matrix[0], new_image[i][j])
        new_imageYCrCb[i][j][1] = np.dot(matrix[1], new_image[i][j],) + 128
        new_imageYCrCb[i][j][2] = np.dot(matrix[2], new_image[i][j],) + 128         
        for z in range(len(new_image[i][j])):            
            if new_imageYCrCb[i][j][z] > 255:
                new_imageYCrCb[i][j][z] = 255
            if new_imageYCrCb[i][j][z] < 0:
                new_imageYCrCb[i][j][z] = 0

new_imageRGB = cv.cvtColor(new_imageYCrCb, cv.COLOR_YCrCb2RGB)

ax[1].imshow(new_imageRGB)
ax[2].imshow(new_imageYCrCb[:, :, 0], cmap="Greys_r")
ax[3].imshow(new_imageYCrCb[:, :, 2], cmap="Greys_r")
ax[4].imshow(new_imageYCrCb[:, :, 1], cmap="Greys_r")

# %% [markdown]
# # Zadanie 4

# %%
import cv2 as cv
import numpy as np
from matplotlib import pyplot as plt

plt.rcParams["figure.figsize"] = (18, 10)
fig, ax = plt.subplots(1, 4)

image = cv.imread("images/example.jpg")
image = cv.cvtColor(image, cv.COLOR_BGR2RGB)

new_image = image.copy()
new_imageYCrCb = image.copy()

matrix = [
    [0.229, 0.587, 0.114],
    [0.500, -0.418, -0.082],
    [-0.168, -0.331, 0.500],
]

for i in range(len(new_image)):
    for j in range(len(new_image[i])):
        new_imageYCrCb[i][j][0] = np.dot(matrix[0], new_image[i][j])
        new_imageYCrCb[i][j][1] = np.dot(matrix[1], new_image[i][j],) + 128
        new_imageYCrCb[i][j][2] = np.dot(matrix[2], new_image[i][j],) + 128         
        for z in range(len(new_image[i][j])):            
            if new_imageYCrCb[i][j][z] > 255:
                new_imageYCrCb[i][j][z] = 255
            if new_imageYCrCb[i][j][z] < 0:
                new_imageYCrCb[i][j][z] = 0

Cb_image = new_imageYCrCb[:, :, 1]
Cr_image = new_imageYCrCb[:, :, 2]

scale_percent = 50 
width = int(Cb_image.shape[1] * scale_percent / 100)
height = int(Cb_image.shape[0] * scale_percent / 100)
dim = (width, height)

Cb_image = cv.resize(Cb_image, dim, interpolation = cv.INTER_AREA)
Cr_image = cv.resize(Cr_image, dim, interpolation = cv.INTER_AREA)

scale_percent = 200 
width = int(Cb_image.shape[1] * scale_percent / 100)
height = int(Cb_image.shape[0] * scale_percent / 100)
dim = (width, height)  

Cb_image = cv.resize(Cb_image, dim, interpolation = cv.INTER_AREA)
Cr_image = cv.resize(Cr_image, dim, interpolation = cv.INTER_AREA)

new_imageYCrCb[:, :, 1] = Cb_image
new_imageYCrCb[:, :, 2] = Cr_image

new_imageRGB = cv.cvtColor(new_imageYCrCb, cv.COLOR_YCrCb2RGB)

ax[0].imshow(new_imageRGB)
ax[1].imshow(new_imageYCrCb[:, :, 0], cmap="Greys_r")
ax[2].imshow(new_imageYCrCb[:, :, 2], cmap="Greys_r")
ax[3].imshow(new_imageYCrCb[:, :, 1], cmap="Greys_r")

# %% [markdown]
# # Zadanie 5

# %%
import cv2 as cv
import numpy as np
from matplotlib import pyplot as plt

image = cv.imread("images/example.jpg")
image = cv.cvtColor(image, cv.COLOR_BGR2RGB)

new_image = image.copy()

matrix = [
    [0.229, 0.587, 0.114],
    [0.500, -0.418, -0.082],
    [-0.168, -0.331, 0.500],
]

for i in range(len(new_image)):
    for j in range(len(new_image[i])):
        new_imageYCrCb[i][j][0] = np.dot(matrix[0], new_image[i][j])
        new_imageYCrCb[i][j][1] = np.dot(matrix[1], new_image[i][j],) + 128
        new_imageYCrCb[i][j][2] = np.dot(matrix[2], new_image[i][j],) + 128         
        for z in range(len(new_image[i][j])):            
            if new_imageYCrCb[i][j][z] > 255:
                new_imageYCrCb[i][j][z] = 255
            if new_imageYCrCb[i][j][z] < 0:
                new_imageYCrCb[i][j][z] = 0

Cb_image = new_imageYCrCb[:, :, 2]
Cr_image = new_imageYCrCb[:, :, 1]

scale_percent = 50 
width = int(Cb_image.shape[1] * scale_percent / 100)
height = int(Cb_image.shape[0] * scale_percent / 100)
dim = (width, height)

Cb_image = cv.resize(Cb_image, dim, interpolation = cv.INTER_AREA)
Cr_image = cv.resize(Cr_image, dim, interpolation = cv.INTER_AREA)

scale_percent = 200 
width = int(Cb_image.shape[1] * scale_percent / 100)
height = int(Cb_image.shape[0] * scale_percent / 100)
dim = (width, height)  

Cb_image = cv.resize(Cb_image, dim, interpolation = cv.INTER_AREA)
Cr_image = cv.resize(Cr_image, dim, interpolation = cv.INTER_AREA)

new_imageYCrCb[:, :, 2] = Cb_image
new_imageYCrCb[:, :, 1] = Cr_image

new_imageRGB = cv.cvtColor(new_imageYCrCb, cv.COLOR_YCrCb2RGB)

mse = np.sum((image.astype("float") - new_imageRGB.astype("float")) ** 2)
mse /= float(3 * image.shape[0] * image.shape[1]) 

print(mse)
